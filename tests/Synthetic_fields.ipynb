# %%
import sys
from netCDF4 import Dataset
import os
import cmocean as cm
from trackeddy.tracking import *
from trackeddy.datastruct import *
from trackeddy.geometryfunc import *
from trackeddy.init import *
from trackeddy.physics import *
from trackeddy.plotfunc import *
from numpy import *
from pylab import *
import cmocean as cm
# %matplotlib inline
# Out:
# /home/156/jm5970/.local/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
def makeGaussian(size, fwhm = 3, center=None):
    """ Make a square gaussian kernel.

    size is the length of a side of the square
    fwhm is full-width-half-maximum, which
    can be thought of as an effective radius.
    """

    x = np.arange(0, size, 1, float)
    y = x[:,np.newaxis]

    if center is None:
        x0 = y0 = size // 2
    else:
        x0 = center[0]
        y0 = center[1]

    return np.exp(-4*np.log(2) * ((x-x0)**2 + (y-y0)**2) / fwhm**2)

def moveGaussian(size,fwhm,center,timestep):
    z=zeros([timestep,size,size])
    for tt in range(0,timestep):
        z[tt,:,:]=makeGaussian(size, fwhm, (center[tt,0],center[tt,1]))
    return z

# %%
zz=moveGaussian(40,10,array([[x,x*0+10] for x in linspace(10,30,40)]),40)
pcolormesh(zz[0,:,:])
colorbar()

# %%
lat=range(0,40)
lon=range(0,40)
eddytdn=analyseddyzt(zz[:,:,:],lon,lat,0,40,1,0.5,0.01,0.01,data_meant='',areamap='',mask=''\
                     ,destdir='',physics='',diagnostics=False,pprint=False)
# Out:
#  0% [=======================================>]100% Time Elapsed: 114 s

# %%
threshold=1
eddysplot=exeddydt(eddytdn,lat,lon,zz[:,:,:],threshold,diagnostics=False)
# Out:
# *******Removing of eddies******
# *******End the Removing of eddies******

# %%
pcolormesh(eddysplot[0,:,:])
figure()
pcolormesh(zz[0,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')
############################
#Create the figure

fig = plt.figure(figsize=(10, 5),facecolor='white')
gs = gridspec.GridSpec(1, 2)

#############################

ax1 = plt.subplot(gs[0,0])

quad1 = ax1.pcolormesh(lon,lat,eddysplot[0,:,:],shading='gouraud',cmap=cm.cm.tempo,\
              vmin=0,vmax=1)
cb1 = fig.colorbar(quad1,ax=ax1)

ax2 = plt.subplot(gs[0,1])

quad2 = ax2.pcolormesh(lon,lat,zz[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-1,vmax=1)
cb2 = fig.colorbar(quad2,ax=ax2)
##############################

##############################
#Intitial stage blank
def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2
##############################

##############################
#Animation function, replace the values of the eke in a '1d list'
def animate(iter):
    quad1.set_array(eddysplot[iter,:,:].ravel())
    quad2.set_array(zz[iter,:,:].ravel())
    return quad1,quad2
##############################

##############################
#Remove edges
gs.tight_layout(fig)
##############################

##############################
#Animation structure
anim2 = animation.FuncAnimation(fig,animate,frames=40,interval=1000,blit=False,repeat=False)
##############################
plt.close()
##############################
#Display and convert animation to html5
anim2
# Out:
# <video width="720" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
zz=ones([40,40])*linspace(0.2,0,40)
zz=zz+moveGaussian(40,10,array([[x,x*0+10] for x in linspace(10,30,40)]),40)

# %%
lat=range(0,40)
lon=range(0,40)
eddytdn=analyseddyzt(zz[:,:,:],lon,lat,0,40,1,0.5,0.01,0.01,data_meant='',areamap='',mask=''\
                     ,destdir='',physics='',diagnostics=False,pprint=False)
# Out:
#  0% [=======================================>]100% Time Elapsed: 121 s

# %%
threshold=1
eddysplot=exeddydt(eddytdn,lat,lon,zz[:,:,:],threshold,diagnostics=False)
# Out:
# *******Removing of eddies******
# *******End the Removing of eddies******

# %%
pcolormesh(eddysplot[0,:,:])
figure()
pcolormesh(zz[0,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')
############################
#Create the figure

fig = plt.figure(figsize=(10, 5),facecolor='white')
gs = gridspec.GridSpec(1, 2)

#############################

ax1 = plt.subplot(gs[0,0])

quad1 = ax1.pcolormesh(lon,lat,eddysplot[0,:,:],shading='gouraud',cmap=cm.cm.tempo,\
              vmin=0,vmax=1)
cb1 = fig.colorbar(quad1,ax=ax1)

ax2 = plt.subplot(gs[0,1])

quad2 = ax2.pcolormesh(lon,lat,zz[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-1,vmax=1)
cb2 = fig.colorbar(quad2,ax=ax2)
##############################

##############################
#Intitial stage blank
def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2
##############################

##############################
#Animation function, replace the values of the eke in a '1d list'
def animate(iter):
    quad1.set_array(eddysplot[iter,:,:].ravel())
    quad2.set_array(zz[iter,:,:].ravel())
    return quad1,quad2
##############################

##############################
#Remove edges
gs.tight_layout(fig)
##############################

##############################
#Animation structure
anim2 = animation.FuncAnimation(fig,animate,frames=40,interval=1000,blit=False,repeat=False)
##############################
plt.close()
##############################
#Display and convert animation to html5
anim2
# Out:
# <video width="720" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
zz=ones([40,40])*linspace(0.2,0,40)
zz=zz+moveGaussian(40,10,array([[40-x,x*0+30] for x in linspace(10,30,40)]),40)+\
    moveGaussian(40,10,array([[x,x*0+10] for x in linspace(10,30,40)]),40)

# %%
lat=range(0,40)
lon=range(0,40)
eddytdn=analyseddyzt(zz[:,:,:],lon,lat,0,40,1,0.5,0.01,0.01,data_meant='',areamap='',mask=''\
                     ,destdir='',physics='',diagnostics=False,pprint=False)
# Out:
#  0% [=======================================>]100% Time Elapsed: 135 s

# %%
threshold=1
eddysplot=exeddydt(eddytdn,lat,lon,zz[:,:,:],threshold,diagnostics=False)
# Out:
# *******Removing of eddies******
# *******End the Removing of eddies******

# %%
pcolormesh(eddysplot[0,:,:])
figure()
pcolormesh(zz[0,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')
############################
#Create the figure

fig = plt.figure(figsize=(10, 5),facecolor='white')
gs = gridspec.GridSpec(1, 2)

#############################

ax1 = plt.subplot(gs[0,0])

quad1 = ax1.pcolormesh(lon,lat,eddysplot[0,:,:],shading='gouraud',cmap=cm.cm.tempo,\
              vmin=0,vmax=1)
cb1 = fig.colorbar(quad1,ax=ax1)

ax2 = plt.subplot(gs[0,1])

quad2 = ax2.pcolormesh(lon,lat,zz[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-1,vmax=1)
cb2 = fig.colorbar(quad2,ax=ax2)
##############################

##############################
#Intitial stage blank
def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2
##############################

##############################
#Animation function, replace the values of the eke in a '1d list'
def animate(iter):
    quad1.set_array(eddysplot[iter,:,:].ravel())
    quad2.set_array(zz[iter,:,:].ravel())
    return quad1,quad2
##############################

##############################
#Remove edges
gs.tight_layout(fig)
##############################

##############################
#Animation structure
anim2 = animation.FuncAnimation(fig,animate,frames=40,interval=1000,blit=False,repeat=False)
##############################
plt.close()
##############################
#Display and convert animation to html5
anim2
# Out:
# <video width="720" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
zz=ones([40,40])*linspace(0.2,0,40)
zz=zz+moveGaussian(40,10,array([[40-x,x*0+30] for x in linspace(10,30,40)]),40)-\
    moveGaussian(40,10,array([[x,x*0+10] for x in linspace(10,30,40)]),40)

# %%
lat=range(0,40)
lon=range(0,40)
eddytdn=analyseddyzt(zz[:,:,:],lon,lat,0,40,1,0.5,0.01,0.01,data_meant='',areamap='',mask=''\
                     ,destdir='',physics='',diagnostics=False,pprint=False)
# Out:
#  0% [=======================================>]100% Time Elapsed: 124 s

# %%
threshold=1
eddysplot=exeddydt(eddytdn,lat,lon,zz[:,:,:],threshold,diagnostics=False)
# Out:
# *******Removing of eddies******
# *******End the Removing of eddies******

# %%
pcolormesh(eddysplot[0,:,:])
figure()
pcolormesh(zz[0,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')
############################
#Create the figure

fig = plt.figure(figsize=(10, 5),facecolor='white')
gs = gridspec.GridSpec(1, 2)

#############################

ax1 = plt.subplot(gs[0,0])

quad1 = ax1.pcolormesh(lon,lat,eddysplot[0,:,:],shading='gouraud',cmap=cm.cm.tempo,\
              vmin=0,vmax=1)
cb1 = fig.colorbar(quad1,ax=ax1)

ax2 = plt.subplot(gs[0,1])

quad2 = ax2.pcolormesh(lon,lat,zz[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-1,vmax=1)
cb2 = fig.colorbar(quad2,ax=ax2)
##############################

##############################
#Intitial stage blank
def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2
##############################

##############################
#Animation function, replace the values of the eke in a '1d list'
def animate(iter):
    quad1.set_array(eddysplot[iter,:,:].ravel())
    quad2.set_array(zz[iter,:,:].ravel())
    return quad1,quad2
##############################

##############################
#Remove edges
gs.tight_layout(fig)
##############################

##############################
#Animation structure
anim2 = animation.FuncAnimation(fig,animate,frames=40,interval=1000,blit=False,repeat=False)
##############################
plt.close()
##############################
#Display and convert animation to html5
anim2
# Out:
# <video width="720" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
zz=ones([20,20])*linspace(0.2,0,20)
zz=zz+moveGaussian(20,7,array([[20-x,x*0+15] for x in linspace(5,15,40)]),40)-\
    moveGaussian(20,7,array([[x,x*0+7.5] for x in linspace(5,15,40)]),40)

# %%
lat=range(0,20)
lon=range(0,20)
eddytdn=analyseddyzt(zz[:,:,:],lon,lat,0,40,1,0.5,0.01,0.01,data_meant='',areamap='',mask=''\
                     ,destdir='',physics='',diagnostics=False,pprint=False)
# Out:
#  0% [=======================================>]100% Time Elapsed: 118 s

# %%
threshold=1
eddysplot=exeddydt(eddytdn,lat,lon,zz[:,:,:],threshold,diagnostics=False)
# Out:
# *******Removing of eddies******
# *******End the Removing of eddies******

# %%
pcolormesh(eddysplot[20,:,:])
figure()
pcolormesh(zz[20,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')
############################
#Create the figure

fig = plt.figure(figsize=(10, 5),facecolor='white')
gs = gridspec.GridSpec(1, 2)

#############################

ax1 = plt.subplot(gs[0,0])

quad1 = ax1.pcolormesh(lon,lat,eddysplot[0,:,:],shading='gouraud',cmap=cm.cm.tempo,\
              vmin=0,vmax=1)
cb1 = fig.colorbar(quad1,ax=ax1)

ax2 = plt.subplot(gs[0,1])

quad2 = ax2.pcolormesh(lon,lat,zz[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-1,vmax=1)
cb2 = fig.colorbar(quad2,ax=ax2)
##############################

##############################
#Intitial stage blank
def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2
##############################

##############################
#Animation function, replace the values of the eke in a '1d list'
def animate(iter):
    quad1.set_array(eddysplot[iter,:,:].ravel())
    quad2.set_array(zz[iter,:,:].ravel())
    return quad1,quad2
##############################

##############################
#Remove edges
gs.tight_layout(fig)
##############################

##############################
#Animation structure
anim2 = animation.FuncAnimation(fig,animate,frames=40,interval=1000,blit=False,repeat=False)
##############################
plt.close()
##############################
#Display and convert animation to html5
anim2
# Out:
# <video width="720" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
zz=ones([20,20])*0.2*sin(linspace(1,2*pi,20))
zz=zz+moveGaussian(20,7,array([[20-x,x*0+15] for x in linspace(5,15,40)]),40)-\
    moveGaussian(20,7,array([[x,x*0+7.5] for x in linspace(5,15,40)]),40)

# %%
lat=range(0,20)
lon=range(0,20)
eddytdn=analyseddyzt(zz[:,:,:],lon,lat,0,40,1,0.5,0.01,0.01,data_meant='',areamap='',mask=''\
                     ,destdir='',physics='',diagnostics=False,pprint=False)
# Out:
#  0% [=======================================>]100% Time Elapsed: 126 s

# %%
threshold=1
eddysplot=exeddydt(eddytdn,lat,lon,zz[:,:,:],threshold,diagnostics=False)
# Out:
# *******Removing of eddies******
# *******End the Removing of eddies******

# %%
pcolormesh(eddysplot[20,:,:])
figure()
pcolormesh(zz[20,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import rc
rc('animation', html='html5')
############################
#Create the figure

fig = plt.figure(figsize=(10, 5),facecolor='white')
gs = gridspec.GridSpec(1, 2)

#############################

ax1 = plt.subplot(gs[0,0])

quad1 = ax1.pcolormesh(lon,lat,eddysplot[0,:,:],shading='gouraud',cmap=cm.cm.tempo,\
              vmin=0,vmax=1)
cb1 = fig.colorbar(quad1,ax=ax1)

ax2 = plt.subplot(gs[0,1])

quad2 = ax2.pcolormesh(lon,lat,zz[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-1,vmax=1)
cb2 = fig.colorbar(quad2,ax=ax2)
##############################

##############################
#Intitial stage blank
def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2
##############################

##############################
#Animation function, replace the values of the eke in a '1d list'
def animate(iter):
    quad1.set_array(eddysplot[iter,:,:].ravel())
    quad2.set_array(zz[iter,:,:].ravel())
    return quad1,quad2
##############################

##############################
#Remove edges
gs.tight_layout(fig)
##############################

##############################
#Animation structure
anim2 = animation.FuncAnimation(fig,animate,frames=40,interval=1000,blit=False,repeat=False)
##############################
plt.close()
##############################
#Display and convert animation to html5
anim2
# Out:
# <video width="720" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
noise = random.normal(0,1,100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ddad50a743ea> in <module>()
# ----> 1 noise = np.random.normal(0,1,100)
#
# NameError: name 'np' is not defined
